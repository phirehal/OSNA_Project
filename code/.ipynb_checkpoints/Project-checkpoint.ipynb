# %%
# This is the ordered execution of all other ipynb files where it will give you some flavour of what we are doing. 
# If you want to know in detail, I suggest running each in the order we are running here individually

# %%
#To run the data collection
# You can skip this cause we have the sample data
# You might a problem in contunuous curl reuqests with Yelp or anything to that matter. Cause those security servers think you are a bot!
# THIS IS EXPECTED TO RUN for 4-5 HOURS (Best case) DEPENDING ON YOUR PROCESSING SPEED AND NETWORK BANDWIDTH
# %run data_collection.ipynb
# Out:
# ***CITY_DATA*** directory already exists
# ***RES_DATA*** directory already exists
# ***GOOGLE_PLACE_DATA*** directory already exists
# ***config*** directory already exists
# ***YELP_REVIEW_DATA*** directory already exists
# ***ZOMATO_DATA*** directory already exists
# Data of 1000 cities retrieved successfully...
# Cuisines we are interested in are: "['Chinese', 'Mexican', 'Italian', 'Sushi', 'Greek', 'French', 'Thai', 'Spanish', 'Indian', 'Mediterranean']"
# [83]
# Now Searching: "New York,NY"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6d8b9edd9f08> in <module>()
#       1 #test= True paramter will only make requests for 5 cities
#       2 #enebaling test=True will run for 50 cities,and full_run=true will run for 500 cities
# ----> 3 url_dict = get_yelp_data(verbose=True,test=True)
#
# ...

# %%
# To run the context classifier that predicts whether the review is about Food,Service or Ambiance
# %run Context_classifier1.ipynb
# Out:
# subdirectories are:['.DS_Store', 'test', 'train']
# found 46 FoodOnly,5 ServiceOnly,3 AmbienceOnly training files
# found 16 FoodOnly,2 ServiceOnly,1 AmbienceOnly testing files
# first 3 and last 3 labels are: [1 1 1 0 0 0]
# ('Total no of train files are:', 54)
# ('Total no of test files are:', 19)
# matrix represents 54 documents with 1222 features
# first doc has terms:
# [26, 34, 38, 43, 47, 50, 54, 56, 58, 59, 78, 89, 92, 111, 118, 121, 128, 141, 152, 155, 161, 163, 176, 185, 195, 203, 205, 218, 270, 271, 315, 324, 325, 326, 350, 412, 414, 422, 424, 437, 444, 454, 476, 488, 504, 512, 518, 533, 535, 547, 581, 589, 592, 612, 653, 654, 663, 667, 672, 677, 682, 694, 713, 732, 741, 773, 774, 834, 853, 868, 923, 956, 1007, 1027, 1050, 1051, 1052, 1053, 1060, 1067, 1079, 1091, 1098, 1117, 1133, 1168, 1172, 1174, 1181, 1185, 1189, 1194, 1197, 1216]
# ...

# %%
#To identify the postive and negative reviews
# %run Classifiers_Pos_Neg.ipynb
# Out:
# subdirectories are:['test', 'train']
# found 79 positive and 33 negative training files
# found 26 positive and 7 negative test files
# first positive file: manual_labels/train/pos/1.txt
# first negative file: manual_labels/train/neg/102.txt
# Most Informative Features
#             contains(ok) = True              neg : pos    =      8.6 : 1.0
#            contains(All) = True              neg : pos    =      8.6 : 1.0
#           contains(oily) = True              neg : pos    =      7.1 : 1.0
#           contains(With) = True              neg : pos    =      7.1 : 1.0
#          contains(still) = True              neg : pos    =      6.1 : 1.0
# first 3 and last 3 labels are: [1 1 1 0 0 0]
# matrix represents 112 documents with 2294 features
# first doc has terms:
# ...

# %%
#To run the word classification in the positve and negative
# %run Feature_word_Classifier.ipynb
# Out:
# subdirectories are:['test', 'train']
# found 79 positive and 33 negative training files
# found 26 positive and 7 negative test files
# first positive file: manual_labels/train/pos/1.txt
# first negative file: manual_labels/train/neg/102.txt
# Now am using all the words as feature set
# train on 342 instances, test on 274 instances
# accuracy: 0.43795620438
# pos precision: 0.432432432432
# pos recall: 0.941176470588
# neg precision: 0.533333333333
# neg recall: 0.0516129032258
# Most Informative Features
#                        2 = True              neg : pos    =     12.4 : 1.0
#                 ordering = True              neg : pos    =      6.9 : 1.0
#                  already = True              neg : pos    =      6.9 : 1.0
#                     Naan = True              neg : pos    =      6.9 : 1.0
#                something = True              neg : pos    =      6.9 : 1.0
#                     give = True              neg : pos    =      6.9 : 1.0
# ...

# %%
# To find the weight of positive or negative words and sorting to know where indian food was weighed more
# EVEN THOUGH WE ONLY PROVIDED A SAMPLE OF NEARLY 50 CITIES THAT WILL END UP 
# AT 0.6M REVIEWS (50 CITIES * 10 CUISINES * 20 RESTAURANTS * 60 REVIEWS)
# SO IT IS EXPECTED TO RUN FOR A LITTLE MORE THAN 30-35 MINS. IT MIGHT INCREASE BASED ON YOUR MACHINE CONFIGURATION
# %run Find_Cuisine_Buzz.ipynb
# Out:
# Cuisines we are interested in are: "['Chinese', 'Mexican', 'Italian', 'Sushi', 'Greek', 'French', 'Thai', 'Spanish', 'Indian', 'Mediterranean']"
# Data of 1000 cities retrieved successfully...
# YELP_REVIEW_DATA/Albany/Chinese.json
# YELP_REVIEW_DATA/Albany/Mexican.json
# YELP_REVIEW_DATA/Albany/Italian.json
# YELP_REVIEW_DATA/Albany/Sushi.json
# YELP_REVIEW_DATA/Albany/Greek.json
# YELP_REVIEW_DATA/Albany/French.json
# YELP_REVIEW_DATA/Albany/Thai.json
# YELP_REVIEW_DATA/Albany/Spanish.json
# YELP_REVIEW_DATA/Albany/Indian.json
# YELP_REVIEW_DATA/Albany/Mediterranean.json
# YELP_REVIEW_DATA/Albuquerque/Chinese.json
# YELP_REVIEW_DATA/Albuquerque/Mexican.json
# YELP_REVIEW_DATA/Albuquerque/Italian.json
# YELP_REVIEW_DATA/Albuquerque/Sushi.json
# YELP_REVIEW_DATA/Albuquerque/Greek.json
# YELP_REVIEW_DATA/Albuquerque/French.json
# YELP_REVIEW_DATA/Albuquerque/Thai.json
# YELP_REVIEW_DATA/Albuquerque/Spanish.json
# YELP_REVIEW_DATA/Albuquerque/Indian.json
# ...
